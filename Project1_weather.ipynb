# %% [markdown]
# #Project 1 weather
# Data analysis by python (pandas)

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np

# %%
#Calculate rolling average for both data frames 
London['London5MA']=London.rolling(window=5).mean()
Global['Global5MA']=Global.rolling(window=5).mean()
#Global

# %%
#Join the data set by indexes/year
df=London.join(Global)
df_copy=df.copy()
df=df.drop(['london_avg', 'global_avg'], axis=1)
#df.tail()

# %%
#line chart plot
lines = df.plot(lw=2,markersize=10, title='Temperature Changes')
lines.set_ylabel('Average temperature (Celsius)')
lines.set_ylim([0,20])
lines.set_xlim([1750,2013])
lines.figure.savefig('figure1.pdf')
print (df.describe())

#Zoomed up line chart
zoom= df.plot(lw=2,markersize=10, title='Temperature Changes')
zoom.set_ylabel('Average temperature (Celsius)')
zoom.set_ylim([6,12])
zoom.set_xlim([1750,2013])
zoom.figure.savefig('figure1_zoom.pdf')
# Out:
#         London5MA   Global5MA
# count  523.000000  520.000000
# mean     8.670887    8.353785
# std      0.937176    0.479343
# min      6.274000    7.108000
# 25%      7.857000    8.043000
# 50%      8.864000    8.317000
# 75%      9.422000    8.624000
# max     10.844000    9.580000
